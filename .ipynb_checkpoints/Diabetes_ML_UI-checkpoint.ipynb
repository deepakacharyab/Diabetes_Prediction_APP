# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('diabetes.csv')

# %%
dataset.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
target = dataset['Outcome']

# %%
dataset = dataset.drop(columns='Outcome', axis=1)

# %%
scalar = StandardScaler()
dataset_s = scalar.fit(dataset)
stan_dataset = dataset_s.transform(dataset)

# %%
X = stan_dataset
Y = target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)
print(X_train.shape, Y_train.shape)
# Out:
# (614, 8) (614,)

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = classifier.predict(X_train)
training_accuracy = accuracy_score(Y_train, X_train_prediction)
print(training_accuracy)
# Out:
# 0.7866449511400652

# %%
X_test_prediction = classifier.predict(X_test)
testing_accuracy = accuracy_score(Y_test, X_test_prediction)
print(X_test[3])
print(Y_test)
# Out:
# [-0.25095213  1.53686099 -0.26394125  1.03272605  1.26076101  0.31824009
#  -0.34996018 -0.27575966]
# 615    0
# 80     0
# 148    0
# 132    1
# 501    0
#       ..
# 127    0
# 185    1
# 85     0
# 497    0
# 86     0
# Name: Outcome, Length: 154, dtype: int64

# %%
import pickle
pickle.dump([classifier, open('diabetes.pkl','wb'))

# Loading model to compare the results
model = pickle.load(open('diabetes.pkl','rb'))
model
# Out:
# SVC(kernel='linear')

# %%
dataset.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
# ...

# %%
# final_features = np.array([6,148,72,35,0,33.6,0.627,50])
# inp_reshape = final_features.reshape(1,-1)
# scalar = StandardScaler()
# dataset_s = scalar.fit(inp_reshape)
# stan_dataset = dataset_s.transform(inp_reshape)



# prediction = model.predict(stan_dataset)

# print(prediction)
# output = round(prediction[0], 2)
# output

# %%
dataset.head(500)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 495            6      166             74              0        0  26.6
# 496            5      110             68              0        0  26.0
# 497            2       81             72             15       76  30.1
# 498            7      195             70             33      145  25.1
# 499            6      154             74             32      193  29.3
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
input_data = (6,148,72,35,0,33.6,0.627,50)
aa = (1,85,66,29,0,26.6,0.3,50)

scalar = StandardScaler()
scalar.fit(dataset)
#stan_dataset = dataset_s.transform(dataset)

input_data_as_np_array = np.array([1,85,66,29,0,26.6,0.3,50])

inp_reshape = input_data_as_np_array.reshape(1,-1)

test_standardize = scalar.transform(inp_reshape)

pred = model.predict(test_standardize)
pred
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-12e3c8eda775> in <module>
#       3
#       4 scalar = StandardScaler()
# ----> 5 scalar.fit()
#       6 #stan_dataset = dataset_s.transform(dataset)
#       7
#
# TypeError: fit() missing 1 required positional argument: 'X'
